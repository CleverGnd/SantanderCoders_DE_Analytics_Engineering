# %% [markdown]
# # Exercícios

# %%
# Importando as bibliotecas
import pandas as pd

# %% [markdown]
# 1. Crie um dataframe de tax_data_2016.csv que usa apenas as colunas específicas necessárias para ver se há diferenças por geografia e nível de renda na composição familiar.
# Para fazer isso, selecione as colunas sobre grupo de renda, são elas: CEP (zipcode), status de declaração de imposto de renda (coluna mars1 para solteiro e MARS2 para casado), e  NUMDEP (número de dependentes).

# %%
# Importando os dados do arquivo csv
path = 'data/us_tax_data_2016.csv'

tax_data_2016 = pd.read_csv(path)

# %%
# Carregando colunas específicas
col_names = ['zipcode', 'mars1', 'MARS2', 'agi_stub', 'NUMDEP']

tax_data_2016_case1 = pd.read_csv(path, usecols=col_names)
tax_data_2016_case1.head()
# Out:
#    zipcode  agi_stub   mars1   MARS2  NUMDEP
# 0        0         1  477700  105350  491310
# 1        0         2  211930  142340  360480
# 2        0         3   83420  137870  182880
# 3        0         4   29420  124060  130160
# 4        0         5   20240  188080  195990

# %% [markdown]
# 2. Obtenha as primeiras 500 linhas em um dataframe chamado primeiras500.
# Em seguida obtenha as próximas 500 linhas em um dataframe proximas500.
#
# Para fazer isso, use os argumentos ``nrows`` e  ``skiprows`` para obter os registros corretos,
# ``header`` para informar aos pandas que os dados não têm nomes de colunas e ``names`` para fornecer os nomes de colunas ausentes.
#
# Depois, nomeie as colunas em proximos500 fornecendo uma lista de colunas de primeiros500 para o argumento ``names``.
# Use a função list() para obter nomes de coluna de primeiros500.

# %%
# Primeiras 500 linhas
primeiras500 = pd.read_csv(path, nrows=500)
primeiras500.head()
# Out:
#    STATEFIPS STATE  zipcode  agi_stub      N1   mars1   MARS2   MARS4    PREP  \
# 0          1    AL        0         1  815440  477700  105350  221200  440830
# 1          1    AL        0         2  495830  211930  142340  128890  272440
# 2          1    AL        0         3  263390   83420  137870   36340  154880
# 3          1    AL        0         4  167190   29420  124060   10610   99700
# 4          1    AL        0         5  217440   20240  188080    4880  129410
#
#         N2  ...  N10300   A10300  N85530  A85530  N85300  A85300  N11901  \
# 0  1296920  ...  367320   330066       0       0       0       0   63420
# 1   996240  ...  398050   984297       0       0       0       0   74090
# 2   584000  ...  253180  1349246       0       0       0       0   64000
# 3   421720  ...  165830  1425430       0       0       0       0   45020
# 4   601040  ...  216720  3922449     390     155      60      19   82940
#
#    A11901  N11902   A11902
# 0   51444  711580  1831661
# 1  110889  416090  1173463
# 2  143060  195130   543284
# 3  128920  117410   381329
# 4  423629  126130   506526
#
# [5 rows x 147 columns]

# %%
# Proximas 500 linhas
col_names = list(primeiras500.columns)

proximas500 = pd.read_csv(path, nrows=500, skiprows=500, header=None, names=col_names)
proximas500.head()
# Out:
#    STATEFIPS STATE  zipcode  agi_stub   N1  mars1  MARS2  MARS4  PREP   N2  \
# 0          1    AL    35178         2  390    150    120    100   200  760
# 1          1    AL    35178         3  230     60    120     50   140  540
# 2          1    AL    35178         4  120     30     90      0    80  280
# 3          1    AL    35178         5  110      0     90      0    80  280
# 4          1    AL    35178         6   20      0     20      0     0   50
#
#    ...  N10300  A10300  N85530  A85530  N85300  A85300  N11901  A11901  \
# 0  ...     320     728       0       0       0       0      50      64
# 1  ...     220    1052       0       0       0       0      50     110
# 2  ...     110     931       0       0       0       0      40      62
# 3  ...     110    1829       0       0       0       0      50     420
# 4  ...      20    1551       0       0       0       0       0       0
#
#    N11902  A11902
# 0     330     926
# 1     170     508
# 2      80     274
# 3      70     295
# 4       0       0
#
# [5 rows x 147 columns]

# %% [markdown]
# 3. Carregue o arquivo tax_data_2016.csv, visualize o atributo dtypes do dataframe e observe os tipos de dados de CEP e agi_stub.

# %%
# Carregando dados de um arquivo csv
tax_data_2016_ex3 = pd.read_csv(path)

# exibe os tipos de dados das colunas 'CEP' e 'agi_stub'
print(tax_data_2016_ex3[['zipcode', 'agi_stub']].dtypes)
# Out:
# zipcode     int64
# agi_stub    int64
# dtype: object

# %% [markdown]
# 4. Você deve ter observado que a coluna agi_stub contém números que correspondem a categorias de renda, e CEP tem valores de 5 dígitos que devem ser strings
# -- tratá-los como inteiros significa que perdemos 0s iniciais, que são significativos.
#
#     Defina os tipos de dados corretos criando um dicionario chamado null_values, especificando que 0s na coluna CEP devem ser considerados valores NA.
#
#     Depois, carregue tax_data_2016.csv, usando o argumento na_values e o dicionário para garantir que CEPs inválidos sejam tratados como ausentes.

# %%
# carrega os dados do arquivo csv e converte os dados da coluna 'zipcode' para string e substitui os valores nulos da coluna 'zipcode' por 0
null_values = {'zipcode': 0}

tax_data_2016_ex4 = pd.read_csv(path, dtype={"zipcode": str}, na_values=null_values)

print(tax_data_2016_ex4[['zipcode', 'agi_stub']].dtypes)
# Out:
# zipcode     object
# agi_stub     int64
# dtype: object

# %%
# exibe as linhas com valores nulos na coluna 'zipcode'
tax_data_2016_ex4[tax_data_2016_ex4.zipcode.isna()]
# Out:
#         STATEFIPS STATE zipcode  agi_stub      N1   mars1   MARS2   MARS4  \
# 0               1    AL     NaN         1  815440  477700  105350  221200
# 1               1    AL     NaN         2  495830  211930  142340  128890
# 2               1    AL     NaN         3  263390   83420  137870   36340
# 3               1    AL     NaN         4  167190   29420  124060   10610
# 4               1    AL     NaN         5  217440   20240  188080    4880
# ...           ...   ...     ...       ...     ...     ...     ...     ...
# 179031         56    WY     NaN         2   61020   32730   17640    9290
# 179032         56    WY     NaN         3   40630   14930   21420    3650
# 179033         56    WY     NaN         4   29160    5770   21390    1340
# 179034         56    WY     NaN         5   38030    3920   32840     770
# 179035         56    WY     NaN         6    8480     850    7090       0
#
#           PREP       N2  ...  N10300   A10300  N85530  A85530  N85300  A85300  \
# 0       440830  1296920  ...  367320   330066       0       0       0       0
# 1       272440   996240  ...  398050   984297       0       0       0       0
# 2       154880   584000  ...  253180  1349246       0       0       0       0
# 3        99700   421720  ...  165830  1425430       0       0       0       0
# 4       129410   601040  ...  216720  3922449     390     155      60      19
# ...        ...      ...  ...     ...      ...     ...     ...     ...     ...
# 179031   28050   113750  ...   52680   146935       0       0       0       0
# 179032   21200    91290  ...   38800   223759       0       0       0       0
# 179033   15960    75150  ...   28790   256930       0       0       0       0
# 179034   22800   105150  ...   37850   714468       0       0      20     121
# 179035    7050    22580  ...    8470  1328573    2320    4642    4780   53835
#
#         N11901  A11901  N11902   A11902
# 0        63420   51444  711580  1831661
# 1        74090  110889  416090  1173463
# 2        64000  143060  195130   543284
# 3        45020  128920  117410   381329
# 4        82940  423629  126130   506526
# ...        ...     ...     ...      ...
# 179031    8970   14465   50770   134347
# 179032    9000   21496   30760    89449
# 179033    6760   20791   21110    74348
# 179034   13230   73326   22250    99589
# 179035    3630  128149    2250   125557
#
# [306 rows x 147 columns]

# %% [markdown]
# 5. Leia o arquivo fcc_survey.xlsx, atribua-o à variável survey_responses e imprima os primeiros registros de survey_responses.

# %%
# Define o caminho do arquivo
path_xlsx = 'data/fcc_survey.xlsx'

# Carrega os dados do arquivo xlsx
survey_responses = pd.read_excel(path_xlsx)

survey_responses.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %% [markdown]
# 6. Crie uma string chamada col_string, especificando que os pandas devem carregar a coluna AD e o intervalo AW até BA.
# Carregue fcc_survey.xlsx, definindo ``skiprows`` e ``usecols`` para ignorar as duas primeiras linhas e obter apenas as colunas em col_string.
# Visualize os nomes das colunas selecionadas no dataframe resultante.

# %%
# Cria uma lista com os nomes das colunas
col_string = "AD, AW:BA"

# Carrega os dados do arquivo xlsx com as colunas especificadas
survey_responses_ex6 = pd.read_excel(path_xlsx, 
                        skiprows=2, 
                        usecols=col_string,
                        header=None)

survey_responses_ex6.head(10)
# Out:
#                          29       48   49   50   51   52
# 0  United States of America  15000.0  0.0  0.0  0.0  1.0
# 1  United States of America  48000.0  0.0  0.0  0.0  0.0
# 2  United States of America  43000.0  0.0  0.0  0.0  1.0
# 3  United States of America   6000.0  1.0  0.0  0.0  1.0
# 4  United States of America  40000.0  0.0  0.0  0.0  0.0
# 5                 Singapore  32000.0  0.0  0.0  1.0  0.0
# 6            United Kingdom  40000.0  1.0  0.0  0.0  0.0
# 7  United States of America  80000.0  0.0  0.0  1.0  0.0
# 8  United States of America  80000.0  0.0  0.0  0.0  1.0
# 9  United States of America  20000.0  0.0  0.0  0.0  1.0

# %% [markdown]
# 7. Crie um dataframe da segunda planilha passando a posição da aba para ``sheet_name``.

# %%
# Carrega os dados do arquivo xlsx usando sheet_name
survey_responses_2017 = pd.read_excel(path_xlsx, sheet_name=1)

survey_responses_2017.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  27.0               0.0             NaN                NaN          NaN
# 1  34.0               0.0             NaN                NaN          NaN
# 2  21.0               0.0             NaN                NaN          NaN
# 3  26.0               0.0             NaN                NaN          NaN
# 4  20.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN            more than 1 million
# 1                NaN             NaN              less than 100,000
# 2                NaN             NaN            more than 1 million
# 3                NaN             NaN  between 100,000 and 1 million
# 4                NaN             NaN  between 100,000 and 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFCC  \
# 0                   NaN                   NaN  ...         NaN
# 1                   NaN                   NaN  ...         1.0
# 2                   NaN                   NaN  ...         NaN
# 3                   NaN                   NaN  ...         1.0
# 4                   NaN                   NaN  ...         NaN
#
#    YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               1.0
# 3                    1.0               NaN               NaN
# 4                    NaN               NaN               NaN
#
#    YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks YouTubeOther  \
# 0                 NaN         NaN                  NaN          NaN
# 1                 NaN         NaN                  NaN          NaN
# 2                 1.0         NaN                  NaN          NaN
# 3                 1.0         NaN                  NaN          NaN
# 4                 NaN         NaN                  NaN          NaN
#
#    YouTubeSimplilearn  YouTubeTheNewBoston
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
#
# [5 rows x 136 columns]

# %% [markdown]
# 8. Carregue as planilhas de 2016 e 2017 por nome.

# %%
# Carrega os dados do arquivo xlsx usando sheet_name para a planilha 2016
survey_responses_2016 = pd.read_excel(path_xlsx, sheet_name='2016')

survey_responses_2016.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
# Carrega os dados do arquivo xlsx usando sheet_name para a planilha 2017
survey_responses_2017 = pd.read_excel(path_xlsx, sheet_name='2017')

survey_responses_2017.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  27.0               0.0             NaN                NaN          NaN
# 1  34.0               0.0             NaN                NaN          NaN
# 2  21.0               0.0             NaN                NaN          NaN
# 3  26.0               0.0             NaN                NaN          NaN
# 4  20.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN            more than 1 million
# 1                NaN             NaN              less than 100,000
# 2                NaN             NaN            more than 1 million
# 3                NaN             NaN  between 100,000 and 1 million
# 4                NaN             NaN  between 100,000 and 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFCC  \
# 0                   NaN                   NaN  ...         NaN
# 1                   NaN                   NaN  ...         1.0
# 2                   NaN                   NaN  ...         NaN
# 3                   NaN                   NaN  ...         1.0
# 4                   NaN                   NaN  ...         NaN
#
#    YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               1.0
# 3                    1.0               NaN               NaN
# 4                    NaN               NaN               NaN
#
#    YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks YouTubeOther  \
# 0                 NaN         NaN                  NaN          NaN
# 1                 NaN         NaN                  NaN          NaN
# 2                 1.0         NaN                  NaN          NaN
# 3                 1.0         NaN                  NaN          NaN
# 4                 NaN         NaN                  NaN          NaN
#
#    YouTubeSimplilearn  YouTubeTheNewBoston
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
#
# [5 rows x 136 columns]

# %% [markdown]
# 9.  Crie um dataframe vazio, chamado df_respostas. Faça um loop for para percorrer os valores no dicionário.
#
#     Adicione cada dataframe a df_respostas e reatribua o resultado à mesma variável.

# %%
# Carrega os dados do arquivo xlsx usando sheet_name para a planilha 2016 e 2017
all_survey = pd.read_excel(path_xlsx, sheet_name=['2016','2017'])

# Criando um DataFrame vazio
df_respostas = pd.DataFrame()

# Concatena os DataFrames através do dicionário all_survey
for key in all_survey:
    df_respostas = pd.concat(all_survey.values())
    
df_respostas
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 18170  41.0               0.0             NaN                   NaN
# 18171  31.0               0.0             NaN                   NaN
# 18172  39.0               0.0             NaN                   NaN
# 18173  54.0               0.0             NaN                   NaN
# 18174  50.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                    NaN                NaN          NaN                 NaN
# 1                    NaN                NaN          NaN                 NaN
# 2                    NaN                NaN          NaN                 NaN
# 3                    NaN                NaN          NaN                 NaN
# 4                    NaN                NaN          NaN                 NaN
# ...                  ...                ...          ...                 ...
# 18170                NaN                NaN          NaN                 NaN
# 18171                NaN                NaN          NaN                 NaN
# 18172                NaN                NaN          NaN                 NaN
# 18173                NaN                NaN          NaN                 NaN
# 18174                NaN                NaN          NaN                 NaN
#
#        BootcampRecommend  ChildrenNumber  ... YouTubeFCC  \
# 0                    NaN             NaN  ...        NaN
# 1                    NaN             NaN  ...        NaN
# 2                    NaN             NaN  ...        NaN
# 3                    NaN             NaN  ...        NaN
# 4                    NaN             NaN  ...        NaN
# ...                  ...             ...  ...        ...
# 18170                NaN             1.0  ...        NaN
# 18171                NaN             1.0  ...        1.0
# 18172                NaN             3.0  ...        1.0
# 18173                NaN             3.0  ...        1.0
# 18174                NaN             2.0  ...        NaN
#
#        YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# 0                        NaN               NaN               NaN
# 1                        NaN               NaN               NaN
# 2                        NaN               NaN               NaN
# 3                        NaN               NaN               NaN
# 4                        NaN               NaN               NaN
# ...                      ...               ...               ...
# 18170                    NaN               NaN               NaN
# 18171                    NaN               NaN               NaN
# 18172                    NaN               NaN               NaN
# 18173                    NaN               NaN               1.0
# 18174                    NaN               NaN               NaN
#
#        YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks  YouTubeOther  \
# 0                     NaN         NaN                  NaN           NaN
# 1                     NaN         NaN                  NaN           NaN
# 2                     NaN         NaN                  NaN           NaN
# 3                     NaN         NaN                  NaN           NaN
# 4                     NaN         NaN                  NaN           NaN
# ...                   ...         ...                  ...           ...
# 18170                 NaN         NaN                  NaN     never see
# 18171                 NaN         NaN                  NaN           NaN
# 18172                 NaN         NaN                  NaN           NaN
# 18173                 NaN         NaN                  1.0           NaN
# 18174                 NaN         NaN                  NaN           NaN
#
#        YouTubeSimplilearn  YouTubeTheNewBoston
# 0                     NaN                  NaN
# 1                     NaN                  NaN
# 2                     NaN                  NaN
# 3                     NaN                  NaN
# 4                     NaN                  NaN
# ...                   ...                  ...
# 18170                 NaN                  NaN
# 18171                 NaN                  NaN
# 18172                 NaN                  1.0
# 18173                 NaN                  NaN
# 18174                 NaN                  NaN
#
# [33795 rows x 163 columns]
